# %%
import random
import queue

# %%
class AdjecencyList:

    class Vertex:
        def __init__(self):
            self.edges = set()

        def add_edge(self, edge):
            self.edges.add(edge)

    class Edge:
        def __init__(self, v1, v2):
            self.vertices = set((v1, v2))
            v1.add_edge(self)
            v2.add_edge(self)

    def __init__(self):
        self.V = set()
        self.E = set()

    def new_vertex(self):
        v = AdjecencyList.Vertex()
        self.V.add(v)
        return v

    def set_edge(self, v1, v2):
        assert v1 is not v2, 'Cycles not supported'
        e = AdjecencyList.Edge(v1, v2)
        self.E.add(e)

    def shortest_path(self, u, v):
        return self.bfs(u, end_at=v)[v]

    def bfs(self, u, end_at=None):
        visited = {u: 0}
        if u is not end_at:
            q = queue.Queue()
            q.put(u)
            while not q.empty():
                v = q.get()
                for edge in v.edges:
                    w = [w for w in edge.vertices if w is not v and w not in visited]
                    if len(w) == 0:
                        continue
                    assert len(w) == 1
                    visited[w[0]] = visited[v] + 1
                    q.put(w[0])
                    if end_at is not None and end_at == w[0]:
                        break
        return visited

    def contract(self):
        while len(self.V) > 2:
            e = random.choice(tuple(self.E))
            v1, v2 = e.vertices
            for v2edge in v2.edges:
                if v1 in v2edge.vertices: # remove loops
                    v1.edges.remove(v2edge)
                    self.E.remove(v2edge)
                else: # replace references to v2 by references to v1, and add edges to v1.edges
                    v2edge.vertices.remove(v2)
                    assert len(v2edge.vertices) == 1
                    v2edge.vertices.add(v1)
                    assert len(v2edge.vertices) == 2
                    v1.edges.add(v2edge)
            self.V.remove(v2) # remove vertex from vertex list
        a, _ = self.V
        return len(a.edges)

# %%
lines = []
with open('kargerMinCut.txt', 'r') as fp:
    for line in fp:
        l = tuple(int(vi)-1 for vi in line.split())
        lines.append(tuple(i for i in l if i >= l[0]))

def get_adjecency_list():
    adj_list = AdjecencyList()
    v = [adj_list.new_vertex() for _ in range(200)]
    for line in lines:
        for vi in line[1:]:
            adj_list.set_edge(v[line[0]], v[vi])
    return adj_list

# %%
# CONTRACTION
adj_list = get_adjecency_list()
m = adj_list.contract()
print("new min: %s" % m)
for _ in range(200): # should be N^2*LOG(n)
    adj_list = get_adjecency_list()
    mnew = adj_list.contract()
    if mnew < m:
        print("new min: %s < %s" % (mnew, m))
        m = mnew
# Out:
# new min: 20
# new min: 17 < 20

# %%
# BFS
adj_list = get_adjecency_list()
v = random.choice(tuple(adj_list.V))
adj_list.bfs(v)
# Out:
# {<__main__.AdjecencyList.Vertex at 0x1120c0048>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2080>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0ac8>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120c00b8>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120c00f0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2588>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120c0128>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0160>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2198>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a21d0>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a2208>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0b00>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0240>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2278>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c05c0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c02b0>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a22e8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a9080>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2320>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0b38>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a2358>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2390>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a25f8>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120c03c8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2400>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a20b8>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2470>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120c04a8>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2b70>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2e80>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a24e0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2518>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2630>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2550>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120c0588>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a20f0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a25c0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0ba8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c05f8>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120c0630>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0668>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2668>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c06a0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2128>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2710>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0748>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2be0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a7630>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2780>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a27b8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a26a0>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120c07f0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2828>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2160>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0860>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0c18>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2438>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120c0898>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c08d0>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a26d8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0908>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0940>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2978>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0278>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a29b0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c09e8>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a2c50>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2a20>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0a58>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a9710>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2da0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0a90>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2ac8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c01d0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2b00>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0c88>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a2b38>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120c0b70>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2748>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2ba8>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0be0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0208>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0c50>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2c88>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0cc0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2cc0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c06d8>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0780>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2d30>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2d68>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2240>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0da0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0cf8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0dd8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x11186b518>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120c0e10>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c07b8>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2e48>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0e80>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a7278>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2ef0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2f28>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0d30>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120c0198>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0f60>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a2f98>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a27f0>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120c0fd0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0080>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a22b0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x11186b048>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0d68>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a7080>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a70b8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0828>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a70f0>: 4,
#  <__main__.AdjecencyList.Vertex at 0x11186b128>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c02e8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a9160>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a7198>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a71d0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a7208>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a7240>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2860>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120a9278>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a72b0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0320>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a72e8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2dd8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a7320>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a7358>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2898>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a7390>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a73c8>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0358>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120a7400>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a9438>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0710>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a74a8>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a74e0>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120a28d0>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a7518>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a7550>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0390>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a7588>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0e48>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a7128>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a75c0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2cf8>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120a75f8>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2908>: 3,
#  <__main__.AdjecencyList.Vertex at 0x11186b630>: 2,
#  <__main__.AdjecencyList.Vertex at 0x11186b668>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a23c8>: 3,
#  <__main__.AdjecencyList.Vertex at 0x11186b6a0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2eb8>: 4,
#  <__main__.AdjecencyList.Vertex at 0x11186b710>: 2,
#  <__main__.AdjecencyList.Vertex at 0x11186b748>: 2,
#  <__main__.AdjecencyList.Vertex at 0x11186b780>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a2940>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2e10>: 2,
#  <__main__.AdjecencyList.Vertex at 0x11186b7f0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0400>: 2,
#  <__main__.AdjecencyList.Vertex at 0x11186b828>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1118eeeb8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x11186b860>: 3,
#  <__main__.AdjecencyList.Vertex at 0x11186b898>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0978>: 0,
#  <__main__.AdjecencyList.Vertex at 0x11186b8d0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2048>: 3,
#  <__main__.AdjecencyList.Vertex at 0x11186b908>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a7470>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120a7438>: 2,
#  <__main__.AdjecencyList.Vertex at 0x11186b940>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0eb8>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0ef0>: 1,
#  <__main__.AdjecencyList.Vertex at 0x11186b080>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c09b0>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120c0470>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c0f28>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a29e8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a7048>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1118eeef0>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120a2c18>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120a24a8>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2f60>: 4,
#  <__main__.AdjecencyList.Vertex at 0x11186b7b8>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120c0a20>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120a7160>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120c04e0>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120c0f98>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2a58>: 4,
#  <__main__.AdjecencyList.Vertex at 0x1120c0438>: 3,
#  <__main__.AdjecencyList.Vertex at 0x112331e48>: 1,
#  <__main__.AdjecencyList.Vertex at 0x1120c0518>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a2fd0>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a9f60>: 2,
#  <__main__.AdjecencyList.Vertex at 0x1120a2a90>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120a9fd0>: 3,
#  <__main__.AdjecencyList.Vertex at 0x1120c0550>: 2}

# %%
# SHORTEST PATH
adj_list = get_adjecency_list()
vertices = tuple(adj_list.V)
v = random.choice(vertices)
u = random.choice(vertices)
adj_list.shortest_path(u, v)
# Out:
# 3

# %%
class DirectedGraph:

    class Vertex:

        def __init__(self, G):
            self.heads = set()
            self.tails = set()
            self.G = G

        def connect_to(self, v_name):
            v = self.G.vertex(v_name)
            if v not in self.heads and self not in v.tails:
                assert v is not self, 'cannot connect a vertex to itself directly'
                self.heads.add(v)
                v.tails.add(self)
            return self

    def __init__(self):
        self.V = dict()

    def vertex(self, v_name):
        if v_name not in self.V:
            self.V[v_name] = DirectedGraph.Vertex(self)
        return self.V[v_name]

    def dfs_topsort(self):
        seen = dict()
        label = len(self.V)
        def recurse(v):
            nonlocal label
            for h in v.heads:
                if h not in seen:
                    seen[h] = -1
                    recurse(h)
            seen[v] = label
            label -= 1
        for k in self.V:
            if self.V[k] not in seen:
                recurse(self.V[k])
        return sorted(((seen[self.V[k]], k) for k in self.V), key=lambda n: n[0])

# %%
g = DirectedGraph()
with open('kargerMinCut.txt', 'r') as fp:
    for line in fp:
        l = tuple(int(vi) for vi in line.split())
        t = g.vertex(l[0])
        for h in l[1:]:
            t.connect_to(h)

# %%
g.dfs_topsort()
# Out:
# [(0, 1),
#  (1, 39),
#  (2, 7),
#  (3, 107),
#  (4, 172),
